# %%
class Converte:
    def __init__(self):
        self.plantas = ["Batata", "Tomate", "Cenoura", "Trigo", "Morango"]
        self.animal = ["Vaca", "Galinha", "Ovelha"]

    def c_semente(self, tipo):
        match tipo:
            case "Semente de Batata":
                return 0

            case "Semente de Tomate":
                return 1

            case "Muda de Cenoura":
                return 2

            case "Semente de Trigo":
                return 3

            case "Semente de Morango":
                return 4

    def c_cercado(self, tipo):
        match tipo:
            case "Vaca":
                return 0

            case "Galinha":
                return 1

            case "Ovelha":
                return 2

    def c_planta(self, tipo):
        return self.plantas[tipo % 10]

    def c_animal(self, tipo):
        return self.animal[tipo % 10]

    def carne(self, t):
        match t:
            case 0:
                return "Carne de Vaca"
            case 1:
                return "Carne de Galinha"
            case 2:
                return "Carne de Ovelha"

# %%
from random import randrange


class Planta:
    def __init__(self, plant):
        # O atributo abaixo recebe o código de uma planta como chave e uma lista
        # com quatro ints. Os significados dos valores seguem são os seguintes:
        # 0. Dias desde que foi plantado
        # 1. Dias em que a planta pegou chuva
        # 2. Dias sem ser regada
        # 3. Dias após a planta estar pronta para ser colhida
        self.plant = plant
        self.converte = Converte()

    def plantar(self, t):
        tipo = self.converte.c_semente(t)
        while self.plant.get(tipo):
            tipo = tipo + 10

        a = [0, 0, 0, 0]
        self.plant[tipo] = a

    def atualiza(self, chuva):
        self.verifica_vida()

        for i in self.plant.keys():
            self.plant[i][0] = self.plant[i][0] + 1

            if chuva == 0:
                self.plant[i][1] = self.plant[i][1] + 1
                self.plant[i][2] = 0
            else:
                self.plant[i][2] = self.plant[i][3] + 1

    def regar(self):
        for i in self.plant.keys():
            self.plant[i][2] = 0

    def colher(self, t):
        tipo = self.converte.c_plantaint(t)
        self.plant.pop(tipo)
        return t, randrange(1, 6)

    def __verifica_vida(self):
        lista = []

        for i in self.plant.keys():
            if self.plant[i][1] == 3 or self.plant[i][2] == 3 or self.plant[i][3] == 3:
                print(f"A {self.converte.c_planta(i)} morreu!!")
                lista.append(i)
                continue

            if self.plant[i][1] == 2:
                print(f"A {self.converte.c_plant(i)} está perto de morrer!")
                continue

            if self.plant[i][2] == 2:
                print(
                    f"A {self.converte.c_plant(i)} está perto de morrer! Lembre de regar ela!!"
                )
                continue

            if self.plant[i][3] == 2:
                print(
                    f"A {self.converte.c_plant(i)} está apodrecendo!! Lembre de colher a sua planta!!"
                )
                continue

        for i in lista:
            self.plant.pop(i)

    def imprime_planta(self):
        print(self.plant)

# %%
from random import randrange


class Cercado:
    def __init__(self, cerca):
        # O atributo abaixo recebe o código de uma planta como chave e uma lista
        # com quatro ints. Os significados dos valores seguem são os seguintes:
        # 0. Dias desde que incluido
        # 1. Dias sem comida
        # 2. Dias sem água

        self.cerca = cerca
        self.converte = Converte()

    def incluir(self, t):
        tipo = self.converte.c_cercado(t)
        while self.cerca.get(tipo):
            tipo = tipo + 10

        a = [0, 0, 0]
        self.cerca[tipo] = a

    def atualiza(self):
        self.verifica_vida()

        for i in self.cerca.keys():
            self.cerca[i][0] = self.cerca[i][0] + 1

            self.cerca[i][1] = self.cerca[i][1] + 1
            self.cerca[i][2] = self.cerca[i][2] + 1

    def dar_agua(self):
        for i in self.cerca.keys():
            self.cerca[i][2] = 0

    def dar_comida(self):
        for i in self.cerca.keys():
            self.cerca[i][1] = 0

    def recolher(self, t, m):
        tipo = self.converte.c_cercado(t)

        if m == False:
            if tipo == 0:
                return "Leite", randrange(1, 6)

            elif tipo == 1:
                return "Ovos", randrange(1, 6)

            else:
                return "Lã", randrange(1, 6)

        else:
            return self.converte.carne(tipo), randrange(1, 6)

    def __verifica_vida(self):
        lista = []

        for i in self.cerca.keys():
            if self.cerca[i][0] == 10 or self.cerca[i][1] == 3 or self.cerca[i][2] == 3:
                print(f"A sua {self.converte.c_animal(i)} morreu!!")
                lista.append(i)
                continue

            if self.cerca[i][0] == 9:
                print(
                    f"A {self.converte.c_animal(i)} está perto de morrer de velhice !!"
                )

            if self.cerca[i][1] == 2:
                print(
                    f"A {self.converte.c_animal(i)} está perto de morrer! Lembre de alimentar ela!!"
                )

            if self.cerca[i][2] == 2:
                print(
                    f"A {self.converte.c_animal(i)} está com sede!! Lembre de dar água para ela!!"
                )

        for i in lista:
            self.cerca.pop(i)

    def imprime_animal(self):
        print(self.cerca)

# %%
class Farmer:
    def __init__(self, inventario):
        self.inventario = inventario
        self.stamina = 0
        self.dinheiro = 0.0
        self.nome = "Pedro"

    def get_inventario(self):
        return self.inventario

    def get_stamina(self):
        return self.stamina

    def get_dinheiro(self):
        return self.dinheiro

    def __verifica_inventario(self):
        if len(self.inventario) > 9:
            return False
        else:
            return True

    def set_inventario(self, item, quant):
        if self.__verifica_inventario:
            if item in self.inventario:
                self.inventario[item] += quant
            else:
                self.inventario[item] = quant

        else:
            print("Oops! O seu inventário está cheio!")

    def set_stamina(self, valor):
        self.stamina += valor

    def set_dinheiro(self, valor):
        self.dinheiro += valor

# %%
class Compras:
    def __init__(self, produtos):
        # O atributo abaixo recebe um dicionário com os produtos da loja

        self.produtos = produtos
        self.__farmer = Farmer({})

    def comprar(self, nome, dinheiro):
        if self.__verifica_nome(nome):
            quant = int(input(f"Entre com o numero de {nome} você quer: "))

            if self.__verifica_dinheiro(dinheiro, self.produtos[nome], quant):
                if quant < 0:
                    quant = quant * -1
                self.__farmer.set_inventario(nome, quant)

    def imprime_loja(self):
        for i in self.produtos.keys():
            print(f"{i}          R${self.produtos[i]}")

    def __verifica_dinheiro(self, dinheiro, preco, quant):
        if dinheiro < preco * quant:
            print("Você não tem dinheiro o bastante para comprar esse item")
            return False
        else:
            return True

    def __verifica_nome(self, nome):
        if nome in self.produtos.keys():
            return True
        else:
            print("Oops! Esse nome não é um nome válido!")
            return False

# %%
from random import randrange


class Loja_p:
    def __init__(self):
        self.produtos = {}

    def adiciona_item(self, nome, quant):
        if nome in self.produtos.keys():
            self.produtos[nome] += quant

        else:
            self.produtos[nome] = quant

    def atualiza_loja(self):
        lista = []
        dinheiro = 0
        for i in self.produtos.keys():
            q = randrange(0, self.produtos[i] + 1)
            if q == self.produtos[i]:
                print(f"Voce vendeu todo o estoque de {i}")
                lista.append(i)
            else:
                print(f"Voce vendeu {q} {i}")
                self.produtos[i] -= q
            dinheiro += q * 10

        for i in lista:
            self.produtos.pop(i)
        return dinheiro

    def imprime_loja(self):
        for i in self.produtos.keys():
            print(f"{i}          R${self.produtos[i]}")

# %%
p = Loja_p()
p.adiciona_item("Tomate",10)
p.imprime_loja()
a = p.atualiza_loja()
print(f"Voce ganhou {a} reais")
a += p.atualiza_loja()
print(f"Voce ganhou {a} reais")
a += p.atualiza_loja()
print(f"Voce ganhou {a} reais")
# Out:
# Tomate          R$10
# Voce vendeu 9 Tomate
# Voce ganhou 90 reais
# Voce vendeu todo o estoque de Tomate
# Voce ganhou 100 reais
# Voce ganhou 100 reais

# %%
dic = {" ": 0}
num = 0
tipo = "Ola"
t = tipo
while dic.get(t):
    num = num + 1
    t = tipo
    t = t + str(num)

tipo = t
dic[tipo] = 1
dic
# Out:
# {' ': 0, 'Ola': 1}

# %%
dick = {"Tokyo": 3, "Los Angeles": 4, "Sao Paulo": [2, 3]}

dick["Sao Paulo"][1] = 4

dick.pop("Tokyo")

dick
# Out:
# {'Los Angeles': 4, 'Sao Paulo': [2, 4]}

# %%
class Geeks:
    def __init__(self):
        self._dinheiro = 0

    def get_dinheiro(self):
        print("getter method called")
        return self._dinheiro

    def set_dinheiro(self, b):
        self._dinheiro += b
